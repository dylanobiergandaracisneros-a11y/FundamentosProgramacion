# %% [markdown]
# <a href="https://colab.research.google.com/github/dylanobiergandaracisneros-a11y/FundamentosProgramacion/blob/main/UNIDAD1/sistemadeprestamosversion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingenieria en Sistemas Computacionales**
# ##**Fundamentos de porgramacion**
# ##**Unidad 1**
# ###**Sistema de gestion de prestamos y reservacion de computadoras-version1**
# Odcente: **Jose Gabriel Rodriguez Rivas**
# Alumno: **Gandara Cisneros Dylan Obier**

# %%
#==============================================================================
# SISTEMA DE PRESTAMOS
#==============================================================================

#lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201", "26040202", "26040203", "26040204"]

#Cada valor en la lista de computadoras tiene su lista correspondiente con el
#aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03","PC-LC3-04"]

AULAS = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC3",
         "LC3", "LC3", "LC3", "LC3"]
software = ["Pynthon, VS Code", "Pynthon, Java, VS Code", "AutoCAD, MATLAB",
            "Pynthon, VS Code", "Pynthon, Java, VS Code", "AutoCAD, MATLAB",
            "Pynthon, VS Code", "Pynthon, Java, VS Code", "AutoCAD, MATLAB", "Pynthon, VS Code"]
estados = [ "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada",
            "Disponible", "Prestada", "Reservada", "Mantenimiento"]

#MENU PRINCIPAL
#Usamos un ciclo While que se repetira indifinidamente hasta que el usuario
#teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
    print("\n===============================")
    print("      SISTEMA DE PRESTAMOS")
    print("\n=============================")
    print("1. Consultar computadoras")
    print("2. Buscar por software")
    print("3. Solicitar prestamo")
    print("4. Devolver computadora")
    print("5. Crear reservacion")
    print("6. Agregar computadora computadora")
    print("7. Salir")
    print("\n============================")
    opcion = int(input("Seleccione una opcion: "))

    if opcion == 1:
        print("\n---COMPUTADORAS---")
        for i in range(len(computadoras)):
            print("Aula: ", AULAS[i],"ID: ", computadoras[i],"Software: ", software[i],"Estado: ", estados[i])
            print("\n-----------------------")
    elif opcion == 2:
        programa = input( "\nIngrese el software que desea buscar: ")
        print("\n---RESULTADOS---")
        encontrado = False
        for i in range(len(computadoras)):
            if programa.lower() in software[i].lower():
                encontrado = True
                print("ID:", computadoras[i])
                print("Aula:", AULAS[i])
                print("Software:", software[i])
                print("Estado:", estados[i])

        if encontrado == False:
            print("No se encontraron computadoras con ese software")
    elif opcion == 3:
        print("\n---SOLICITAR PRESTAMO---")
        num_control = input( "\nIngrese su numero de control: ")
        encontrado1 = False
        if num_control in alumnos:
          programa = input("Que prpgrama necesitas")
          for i in range(len(computadoras)):
            if programa.lower() in software[i].lower():
              if estados [i]=="Disponible":
                estados[i]="Prestada"
                print("Se asigno la computadora", computadoras[i], "que esta en el aula", aulas[i])
                break
              else:
                print("si se encontro el software pero esta", estados[i])
  else:
    print("El alumno no existe en la lista")
            encontrado1 = True
            id_computadora = input("Ingrese el ID de la computadora: "  )
            encontrado2 = False
            for i in range(len(computadoras)):
                if computadoras[i] == id_computadora:
                    encontrado2 = True
                    if estados[i] == "Disponible":
                        estados[i] = "Prestada"
                        print("Prestamo registrado correctamente.")
                        print("Computadora:", computadoras[i])
                        print("Aula", AULAS[i])
                    else:
                        print("La computadora no esta disponible")
            if encontrado2 == False:
                print("La computadora no existe.")
        if encontrado1 == False:
          print("el alumno no existe.")
    elif opcion == 4:
        print("Opción 4: Devolver computadora (Funcionalidad no implementada aún).")
    elif opcion == 5:
        print("Opción 5: Crear reservación (Funcionalidad no implementada aún).")
    elif opcion == 6:
        print("\n---AGREGAR COMPUTADORA---")
        id_computadora = input("ID de la computadora: ")
        aula = input("Aula: ")
        programas = input("Softwares instalado: ")
        computadoras.append(id_computadora)
        AULAS.append(aula)
        software.append(programas)
        estados.append("Disponible")
        print("Computadora agregada correctamente")
    elif opcion == 7:
        print("Saliendo del sistema. ¡Hasta luego!")
        break
    else:
        print("Opción inválida. Por favor, seleccione una opción entre 1 y 7.")
# Out:
# ===============================
#       SISTEMA DE PRESTAMOS
#
# =============================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora computadora
# 7. Salir
#
# ============================
# Seleccione una opcion: 1
#
# ---COMPUTADORAS---
# Aula:  LC1 ID:  PC-LC1-01 Software:  Pynthon, VS Code Estado:  Disponible
#
# -----------------------
# Aula:  LC1 ID:  PC-LC1-02 Software:  Pynthon, Java, VS Code Estado:  Prestada
#
# -----------------------
# Aula:  LC1 ID:  PC-LC1-03 Software:  AutoCAD, MATLAB Estado:  Reservada
#
# -----------------------
# Aula:  LC2 ID:  PC-LC2-01 Software:  Pynthon, VS Code Estado:  Disponible
#
# -----------------------
# Aula:  LC2 ID:  PC-LC2-02 Software:  Pynthon, Java, VS Code Estado:  Prestada
#
# -----------------------
# Aula:  LC3 ID:  PC-LC2-03 Software:  AutoCAD, MATLAB Estado:  Reservada
#
# -----------------------
# Aula:  LC3 ID:  PC-LC3-01 Software:  Pynthon, VS Code Estado:  Disponible
#
# -----------------------
# Aula:  LC3 ID:  PC-LC3-02 Software:  Pynthon, Java, VS Code Estado:  Prestada
#
# -----------------------
# Aula:  LC3 ID:  PC-LC3-03 Software:  AutoCAD, MATLAB Estado:  Reservada
#
# -----------------------
# Aula:  LC3 ID:  PC-LC3-04 Software:  Pynthon, VS Code Estado:  Mantenimiento
#
# -----------------------
#
# ===============================
#       SISTEMA DE PRESTAMOS
#
# =============================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora computadora
# 7. Salir
#
# ============================
# Seleccione una opcion: 2
#
# Ingrese el software que desea buscar: 3
#
# ---RESULTADOS---
# No se encontraron computadoras con ese software
#
# ===============================
#       SISTEMA DE PRESTAMOS
#
# =============================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora computadora
# 7. Salir
#
# ============================
# Seleccione una opcion: 5
# Opción 5: Crear reservación (Funcionalidad no implementada aún).
#
# ===============================
#       SISTEMA DE PRESTAMOS
#
# =============================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora computadora
# 7. Salir
#
# ============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_839/461199884.py in <cell line: 0>()
#      38     print("7. Salir")
#      39     print("\n============================")
# ---> 40     opcion = int(input("Seleccione una opcion: "))
#      41
#      42     if opcion == 1:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
