# %% [markdown]
# <a href="https://colab.research.google.com/github/dylanobiergandaracisneros-a11y/FundamentosProgramacion/blob/main/unidad1/programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 5
X= "hola mundo"
X = True
print("El valor de x es", X )
# Out:
# El valor de x es True

# %%
base = int(input("Dame la base del triangulo") )
altura= int(input("dame la altura del triangulo") )
area = (base * altura)/2
print ("el area del triangulo es", area)
# Out:
# Dame la base del triangulo10
# dame la altura del triangulo20
# el area del triangulo es 100.0

# %%
variable1= 30
variable2= 50
if variable1 > variable2:
   print("la variable 1 es mayor a la variable 2")
else:
   print("la variable 2 es mayor a la variable 1")
# Out:
# la variable 2 es mayor a la variable 1

# %%
variable1= 30
variable2= 50
if variable1 > variable2:
   print( variable1, "es mayor que", variable2 )
else:
   print( variable2, "es mayor que", variable1 )
# Out:
# 50 es mayor que 30

# %%
variable1= 70
variable2= 70
if variable1 > variable2:
   print( variable1, "es mayor que", variable2 )
elif variable1 == variable2:
   print( variable1, "es igual que", variable2)
else:
   print( variable2, "es mayor que", variable1 )
# Out:
# 70 es igual que 70

# %%
edad= int(input("Dame tu edad"))
if edad <= 10:
   print("Eres un niño")
elif edad <= 18:
   print("Eres un adolescente")
elif edad <= 30:
   print("Eres un joven adulto")
elif edad <= 67:
   print("eres un adulto")
elif edad <= 100:
   print("eres un anciano")
else:
   print("edad incorrecta")
# Out:
# Dame tu edad65
# eres un adulto

# %%
edad= int(input("Dame tu edad"))
if edad >= 100:
   print("Eres un anciano")
elif edad >= 67:
   print("Eres un adulto")
elif edad >= 30:
   print("Eres un joven adulto")
elif edad >= 18:
   print("Eres un adolescente")
elif edad >= 10:
   print("Eres un niño")
else:
   print("edad incorrecta")
# Out:
# Dame tu edad87
# Eres un adulto

# %%
edad= int(input("Dame tu edad"))
if edad <= 100:
   print("Eres un anciano")
elif edad <= 67:
   print("Eres un adulto")
elif edad <= 30:
   print("Eres un joven adulto")
elif edad <= 18:
   print("Eres un adolescente")
elif edad <= 10:
   print("Eres un niño")
else:
   print("edad incorrecta")
# Out:
# Dame tu edad20
# Eres un anciano

# %%
12 > 5 #esto es un comentario, el resultado es un valor boleano
       #que me regresa verdadero o falso dependiendo si se cumple la condicion
# Out:
# True

# %%
10 >5 and 10 > 7 and 10 > 1
# Out:
# True

# %%
#tenemos 3 condciones con el operador or con que se cumpla una sera el resultado True
10 >5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
#la condicion de and me sirvio para poner un rango de edades mas establecido para saber que cantidad le corresponde a que edad
edad= int(input("Dame tu edad"))
if edad >= 100:
   print("Eres un anciano")
elif edad >= 67 and edad <=99:
   print("Eres un adulto")
elif edad >= 30 and edad <=66:
   print("Eres un joven adulto")
elif edad >= 18 and edad <=29:
   print("Eres un adolescente")
elif edad >= 10 and edad <17:
   print("Eres un niño")
else:
   print("edad incorrecta")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_422/1292064951.py in <cell line: 0>()
#       1 #la condicion de and me sirvio para poner un rango de edades mas establecido para saber que cantidad le corresponde a que edad
# ----> 2 edad= int(input("Dame tu edad"))
#       3 if edad >= 100:
#       4    print("Eres un anciano")
#       5 elif edad >= 67 and edad <=99:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
# instruccion for, sirve para escribir instruccines
tabla = 8
for i in range(10):
  print (tabla, "*", i, "=", tabla*i)
# Out:
# 8 * 0 = 0
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72

# %%
tabla = 7
 for i in range(10, 100, 5):
  print (tabla, "*", i, "=", tabla*i)
# Out:
#   File "/tmp/ipykernel_1811/3237509833.py", line 2
#     for i in range(10, 100, 5):
#     ^
# IndentationError: unexpected indent

# %%
edad= int(input("Dame tu edad"))
if edad >= 100:
   print("Eres un anciano")
elif edad >= 67 and edad <=99:
   print("Eres un adulto")
elif edad >= 30 and edad <=66:
   print("Eres un joven adulto")
elif edad >= 18 and edad <=29:
   print("Eres un adolescente")
elif edad >= 10 and edad <17:
   print("Eres un niño")
else:
   print("edad incorrecta")

# %%
## En este codigo aprendimos a poner emmmmmmmmmm no se w estudiale xd

tabla = int(input("dame el valor de la tabla de multiplicar que deseas"))
valor_inicial =int(input ("escribe el valor inicial"))
valor_final =int(input ("escribe el valor final"))
incremento =int(input ("escribe el incremento"))
for i in range(valor_inicial, valor_final, incremento):
  print (tabla, "*", i, "=", tabla*i)
# Out:
# dame el valor de la tabla de multiplicar que deseas7
# escribe el valor inicial10
# escribe el valor final120
# escribe el incremento3
# 7 * 10 = 70
# 7 * 13 = 91
# 7 * 16 = 112
# 7 * 19 = 133
# 7 * 22 = 154
# 7 * 25 = 175
# 7 * 28 = 196
# 7 * 31 = 217
# 7 * 34 = 238
# 7 * 37 = 259
# 7 * 40 = 280
# 7 * 43 = 301
# 7 * 46 = 322
# 7 * 49 = 343
# 7 * 52 = 364
# 7 * 55 = 385
# 7 * 58 = 406
# 7 * 61 = 427
# 7 * 64 = 448
# 7 * 67 = 469
# 7 * 70 = 490
# 7 * 73 = 511
# 7 * 76 = 532
# 7 * 79 = 553
# 7 * 82 = 574
# 7 * 85 = 595
# 7 * 88 = 616
# 7 * 91 = 637
# 7 * 94 = 658
# 7 * 97 = 679
# 7 * 100 = 700
# 7 * 103 = 721
# 7 * 106 = 742
# 7 * 109 = 763
# 7 * 112 = 784
# 7 * 115 = 805
# 7 * 118 = 826

# %%
numero = 1
while numero < 5:
  print(numero)
  print ("dentro de while")
  numero = numero + 1
print ("fuera de while")
# Out:
# 1
# dentro de while
# 2
# dentro de while
# 3
# dentro de while
# 4
# dentro de while
# fuera de while

# %%
tabla = int(input("dame el valor de la tabla de multiplicar que deseas"))
valor_inicial =int(input ("escribe el valor inicial"))
valor_final =int(input ("escribe el valor final"))
incremento =int(input ("escribe el incremento"))
#Agregamos la instruccion while para que valide el valor inicial sea mayor que el final
while valor_inicial>= valor_final:
  print ("el limite final debe ser mayor que el inicial")
  final =int(input ("Dame el limite final"))

for i in range(valor_inicial, valor_final, incremento):
  print (tabla, "*", i, "=", tabla*i)
# Out:
# dame el valor de la tabla de multiplicar que deseas10
# escribe el valor inicial10
# escribe el valor final2
# escribe el incremento2
# el limite final debe ser mayor que el inicial
# Dame el limite final12
# el limite final debe ser mayor que el inicial
# Dame el limite final12
# el limite final debe ser mayor que el inicial
# Dame el limite final12
# el limite final debe ser mayor que el inicial
# Dame el limite final12
# el limite final debe ser mayor que el inicial
# Dame el limite final12
# el limite final debe ser mayor que el inicial
# Dame el limite final
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_552/1823610072.py in <cell line: 0>()
#       6 while valor_inicial>= valor_final:
#       7   print ("el limite final debe ser mayor que el inicial")
# ----> 8   final =int(input ("Dame el limite final"))
#       9
# ...

# %% [markdown]
# # LISTAS EN PYNTHON

# %%
alumnos = ["ana","Luis", "Carlos"]
print (alumnos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_552/1503748069.py in <cell line: 0>()
#       1 alumnos = ["ana","Luis", "Carlos"]
# ----> 2 print (alumnos)
#
# TypeError: 'list' object is not callable
